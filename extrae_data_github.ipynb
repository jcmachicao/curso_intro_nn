# %% [markdown]
# <a href="https://colab.research.google.com/github/jcmachicao/curso_intro_nn/blob/main/extrae_data_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# para archivos CSV
urldata_1 = 'https://raw.githubusercontent.com/jcmachicao/curso_intro_nn/main/datasets/ActosViolentos.csv'

# para archivos XLSX
urldata_2 = 'https://github.com/jcmachicao/curso_intro_nn/raw/main/datasets/bd_manzanas.xlsx'
urldata_2b = 'https://github.com/jcmachicao/curso_intro_nn/blob/main/datasets/bd_manzanas.xlsx?raw=true'

# %%
import pandas as pd

# %%
data_1 = pd.read_csv(urldata_1, encoding='latin-1')
data_1.head()
# Out:
#    Edad  Hora Sexo Area  Ingreso     Violento
# 0  Niño    17    M   A1        2     Violento
# 1  Niño     3    F   A3        4  No Violento
# 2  Niño    19    F   A1        3     Violento
# 3  Niño    23    M   A1        2  No Violento
# 4  Niño     7    F   A2        5     Violento

# %%
import pandas as pd
import requests

# %%
myfile = requests.get(urldata_2)
data_2 = pd.read_excel(myfile.content)
data_2.head()
# Out:
#    peso         aroma  precio  diametro   color      estado
# 0  61.0     agradable     3.0       7.7  marron  comestible
# 1  61.0     agradable     4.0       8.0    rojo  comestible
# 2  55.0     agradable     5.0       6.2    rojo  comestible
# 3  48.0  desagradable     4.0       6.1  marron   malograda
# 4  50.0     agradable     2.0       5.9  marron   malograda

# %%
data_2b = pd.read_excel(urldata_2b)
data_2b.head()
# Out:
#    peso         aroma  precio  diametro   color      estado
# 0  61.0     agradable     3.0       7.7  marron  comestible
# 1  61.0     agradable     4.0       8.0    rojo  comestible
# 2  55.0     agradable     5.0       6.2    rojo  comestible
# 3  48.0  desagradable     4.0       6.1  marron   malograda
# 4  50.0     agradable     2.0       5.9  marron   malograda
